# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here

import warnings
warnings.simplefilter('ignore')

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import pandas as pd
pd.set_option('display.max_columns', None)

import scipy.stats as stats

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('/Users/JGR/IRON_HACK/5.1-lab-subsetting-and-descriptive-stats/your-code/Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %%
# We have 7 rows and 3 columns, NO nuls.

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
ny = temp[temp['State'] == 'New York']
ny
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
ny_avg_temp = ny.iloc[:]['Temperature'].mean()
print("The Temperature's average of NY is:", ny_avg_temp)
# Out:
# The Temperature's average of NY is: 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer heret
filtered_temp = temp[temp['Temperature'] > 15]
filtered_temp[['State', 'Temperature']]
# Out:
#          State  Temperature
# 0     New York    19.444444
# 3  Connecticut    17.222222
# 5   New Jersey    22.222222
# 6   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
filtered_temp = temp[temp['Temperature'] > 15]
filtered_temp[['State']]
# Out:
#          State
# 0     New York
# 3  Connecticut
# 5   New Jersey
# 6   New Jersey

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
filtered_temp = temp[(temp['Temperature'] > 15) & (temp['Temperature'] < 20)]
filtered_temp[['State', 'Temperature']]
# Out:
#          State  Temperature
# 0     New York    19.444444
# 3  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
mean_std_dev = temp.groupby('State')['Temperature'].agg(['mean', 'std'])
mean_std_dev
# Out:
#                   mean       std
# State
# Connecticut  15.833333  1.964186
# New Jersey   21.111111  1.571348
# New York     10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employeee = pd.read_csv('/Users/JGR/IRON_HACK/5.1-lab-subsetting-and-descriptive-stats/your-code/Employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
employee # Datos generales de los empleados, dept. educ. sex. titulo, años y salario
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %%
# your answer here
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Department  9 non-null      object
#  2   Education   9 non-null      object
#  3   Gender      9 non-null      object
#  4   Title       9 non-null      object
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 632.0+ bytes

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here

plt.hist(employee['Salary'],bins=20, color='purple')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Histogram of Employee Year')
plt.show()

# tenemos 2 employees con 30K, 2 con 35K, 2 con 55K, 1 con 60K y 2 con 70K

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
salary_mean = employee['Salary'].mean()
print('The average Salary of this company is:',salary_mean)
# Out:
# The average Salary of this company is: 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
salary_max = employee['Salary'].max()
print('The maximum Salary of this company is:',salary_max, 'K')
# Out:
# The maximum Salary of this company is: 70 K

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
salary_min = employee['Salary'].min()
print('The maximum Salary of this company is:',salary_min, 'K')
# Out:
# The maximum Salary of this company is: 30 K

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here

lowest_salary = employee[employee['Salary'] == employee['Salary'].min()]
lowest_salary_names = lowest_salary['Name']
lowest_salary_names
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
david_info = employee.loc[employee['Name'] == 'David']
david_info
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
david_info = employee.loc[employee['Name'] == 'David']

# imprimir el salario del empleado llamado "David"
david_info['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
associates = employee.loc[employee['Title'] == 'associate']
associates
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
filtro = employee.loc[(employee['Title'] == 'associate') & (employee['Salary'] > 55)]

filtro
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
grouped = employee.groupby('Years')['Salary'].mean()
grouped
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
grouped = employee.groupby('Title')['Salary'].mean()
grouped
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here

plt.boxplot(employee['Salary'])
plt.title('Salary Boxplot')
plt.ylabel('Salary')
plt.show()

# calcula el primero y el tercer cuartile. 
q1 = employee['Salary'].quantile(0.25)
q3 = employee['Salary'].quantile(0.75)
print('First Quartile (Q1):', q1)
print('Third Quartile (Q3):', q3)
# Out:
# First Quartile (Q1): 35.0
# Third Quartile (Q3): 60.0

# %%
# print first quartile here
q1 = employee['Salary'].quantile(0.25)
q1
# Out:
# 35.0

# %%
# print third quartile here
q3 = employee['Salary'].quantile(0.75)
q3
# Out:
# 60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
sns.barplot(x='Gender', y='Salary', data=employee, estimator=lambda x: sum(x)/len(x))
plt.title('Mean Salary by Gender')
plt.ylabel('Mean Salary')
plt.show()

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here

grouped = employee.groupby('Department')

# calculate the minimum, mean, and maximum for each department
result = grouped.aggregate({'Years': ['min', 'mean', 'max'], 'Salary': ['min', 'mean', 'max']})

# print the result
result
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
salary_diff = lambda x: x.max() - x.min()
result = employee.groupby('Department')['Salary'].agg(salary_diff)
result
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# Name: Salary, dtype: int64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('/Users/JGR/IRON_HACK/5.1-lab-subsetting-and-descriptive-stats/your-code/Orders.csv')
orders.head(10)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
# 5           5     536365     22752  2010     12    3     8
# 6           6     536365     21730  2010     12    3     8
# 7           7     536366     22633  2010     12    3     8
# 8           8     536366     22632  2010     12    3     8
# 9           9     536367     84879  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %%
# your answer here
orders.describe().T
# Out:
#                  count           mean            std       min        25%  \
# Unnamed: 0    397924.0  278465.221859  152771.368303       0.0  148333.75
# InvoiceNo     397924.0  560617.126645   13106.167695  536365.0  549234.00
# year          397924.0    2010.934259       0.247829    2010.0    2011.00
# month         397924.0       7.612537       3.416527       1.0       5.00
# day           397924.0       3.614555       1.928274       1.0       2.00
# hour          397924.0      12.728247       2.273535       6.0      11.00
# Quantity      397924.0      13.021823     180.420210       1.0       2.00
# UnitPrice     397924.0       3.116174      22.096788       0.0       1.25
# CustomerID    397924.0   15294.315171    1713.169877   12346.0   13969.00
# amount_spent  397924.0      22.394749     309.055588       0.0       4.68
#
#                     50%        75%        max
# Unnamed: 0    284907.50  410079.25  541908.00
# InvoiceNo     561893.00  572090.00  581587.00
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here

average_price = orders['amount_spent'].mean()
average_price
# Out:
# 22.39474850474768

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
highest_price = orders['amount_spent'].max()
print(f"The highest purchase price is: {highest_price}")
# Out:
# The highest purchase price is: 168469.6

# %%
lowest_price = orders['amount_spent'].min()
print(f"The lowest purchase price is: {lowest_price}")
# Out:
# The lowest purchase price is: 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
country = orders[orders['Country'] == 'Spain']
country
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
spanish_cust = orders[orders['Country'] == 'Spain'].groupby(['CustomerID'])
spanish_cust.count()
# Out:
#             Unnamed: 0  InvoiceNo  StockCode  year  month  day  hour  \
# CustomerID
# 12354               58         58         58    58     58   58    58
# 12417               23         23         23    23     23   23    23
# 12421               45         45         45    45     45   45    45
# 12442               12         12         12    12     12   12    12
# 12445                4          4          4     4      4    4     4
# 12448               22         22         22    22     22   22    22
# 12450                8          8          8     8      8    8     8
# 12454               15         15         15    15     15   15    15
# 12455               48         48         48    48     48   48    48
# 12462               62         62         62    62     62   62    62
# 12484              346        346        346   346    346  346   346
# 12502              147        147        147   147    147  147   147
# ...

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
customers_purch = orders[orders['Quantity'] > 50]

# print the result
customers_purch
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 174            176     536386    85099C  2010     12    3     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 397720      541702     581566     23404  2011     12    5    11
# 397721      541703     581567     21417  2011     12    5    11
# 397729      541711     581567     21326  2011     12    5    11
# 397761      541746     581571     23167  2011     12    5    12
# 397882      541867     581584     20832  2011     12    5    12
#
#                                Description  Quantity          InvoiceDate  \
# 46         paper chain kit 50's christmas         80  2010-12-01 09:00:00
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
orders_over_50_from_spain = orders[(orders['Country'] == 'Spain') & (orders['Quantity'] > 50)]

# print the result
orders_over_50_from_spain
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
free_price = orders[orders['UnitPrice']== 0]
free_price
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
lunch_bags = orders[orders['Description'].str.contains('lunch bag', case=False)]
lunch_bag
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, InvoiceNo, StockCode, year, month, day, hour, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, amount_spent]
# Index: []

# %%
orders['Description']
# Out:
# 0          white hanging heart t-light holder
# 1                         white metal lantern
# 2              cream cupid hearts coat hanger
# 3         knitted union flag hot water bottle
# 4              red woolly hottie white heart.
#                          ...
# 397919            pack of 20 spaceboy napkins
# 397920           children's apron dolly girl
# 397921          childrens cutlery dolly girl
# 397922        childrens cutlery circus parade
# 397923          baking set 9 piece retrospot
# Name: Description, Length: 397924, dtype: object

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
